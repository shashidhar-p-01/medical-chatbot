# %%
# imports the environment variables

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\appu\anaconda3\lib\site-packages (6.14.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# LOADING THE PDF 
#PyPDFLoader - extracts text from pdf , one page at a time 
#DirectoryLoader - scans folder and finds everything matching the filetye

from langchain_community.document_loaders import PyPDFLoader , DirectoryLoader

DATA_PATH = "data/"

def load_pdf_files(data):
    loader = DirectoryLoader(data , glob = "*.pdf" , loader_cls = PyPDFLoader)
    documents = loader.load()
    return documents 

documents = load_pdf_files(DATA_PATH)

print(f"number of pages loaded : {len(documents)}")
# Out:
# C:\Users\APPU\AppData\Local\Temp\ipykernel_29968\3547835385.py:5: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader , DirectoryLoader
# number of pages loaded : 759

# %%
#checking if it works 
print(documents[0])
# Out:
# page_content='The GALE
# ENCYCLOPEDIA
# of MEDICINE
# SECOND EDITION' metadata={'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-05-01T10:37:35-07:00', 'moddate': '2017-05-01T10:37:35-07:00', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'source': 'data\\The_GALE_ENCYCLOPEDIA_of_MEDICINE_SECOND.pdf', 'total_pages': 759, 'page': 0, 'page_label': '1'}

# %%
# CHUNKING
#ResursiveCharacterTextSplitter - is "recursive" because it tries to cut at the best possible boundary: first tries paragraph 
#breaks (\n\n), then line breaks (\n), then sentences, then words, only falling back to a hard character cut as a last resort

from langchain_text_splitters import RecursiveCharacterTextSplitter

def create_chunks(extracted_data) : 
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = 500 , # max ~500 characters per chunk (not words, not tokens — raw characters)
        chunk_overlap = 50 # the last 50 characters of one chunk get repeated as the first 50 characters of the next chunk.
    )
    text_chunks = text_splitter.split_documents(extracted_data)
    return text_chunks

text_chunks = create_chunks(documents)
print("number of chunks created : " , len(text_chunks))
# Out:
# number of chunks created :  7080

# %%
pip install langchain_huggingface
# Out:
# Requirement already satisfied: langchain_huggingface in c:\users\appu\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\appu\anaconda3\lib\site-packages (from langchain_huggingface) (1.20.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\appu\anaconda3\lib\site-packages (from langchain_huggingface) (1.4.8)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\appu\anaconda3\lib\site-packages (from langchain_huggingface) (0.22.2)
# Requirement already satisfied: click>=8.4.0 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.67.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.20.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\appu\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.15.0)
# Requirement already satisfied: anyio in c:\users\appu\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.10.0)
# Requirement already satisfied: certifi in c:\users\appu\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\appu\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\appu\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\appu\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\appu\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\appu\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\appu\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.9.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\appu\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.12.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\appu\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\appu\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\appu\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.0.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\appu\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\appu\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\appu\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\appu\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\appu\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\appu\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\appu\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.8.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\appu\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\appu\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\appu\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\appu\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\appu\anaconda3\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\appu\anaconda3\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (14.2.0)
# Requirement already satisfied: colorama in c:\users\appu\anaconda3\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\appu\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\appu\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\appu\anaconda3\lib\site-packages (from rich>=10.11.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\appu\anaconda3\lib\site-packages (from rich>=10.11.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\appu\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# embeddings - turninf text into vectors 
from langchain_huggingface import HuggingFaceEmbeddings

def get_embedding_model():
    embedding_model = HuggingFaceEmbeddings(model_name = "sentence-transformers/all-MiniLM-L6-v2")
    return embedding_model

embedding_model = get_embedding_model()
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
#build and save FAISS index 

from langchain_community.vectorstores import FAISS

DB_FAISS_PATH = "vectorstore/db_faiss"
db = FAISS.from_documents(text_chunks , embedding_model)
db.save_local(DB_FAISS_PATH)

print("FAISS index saved to : " , DB_FAISS_PATH)
# Out:
# FAISS index saved to :  vectorstore/db_faiss
